# %%
from ipynb.fs.full.Mimic import *
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
def generate_evil_data(size, num_clusters, num_dims, num_bias, drop_min=0.05, plot=False, seed=None, spread=40):
    if num_bias > num_clusters: num_bias=num_clusters
    while True:
        if seed is None: seed = np.random.randint(1000, 9999)
        clf = SVC(random_state=seed)
        rng = np.random.default_rng(seed)
            
        # generate dataset
        data1, labels1 = generatePills(int(size/2), num_clusters, num_dims, mean_low=spread, mean_high=spread+1, seed=seed)
        data2, labels2 = generatePills(int(size/2), num_clusters, num_dims, mean_low=spread, mean_high=spread+1, seed=seed+1)
    
        # split into test/train
        idcs_test1 = rng.choice(range(len(data1)), int(0.3*len(data1)))
        idcs_test2 = rng.choice(range(len(data2)), int(0.3*len(data2)))       
        idcs_train1 = np.setdiff1d(range(len(data1)), idcs_test1)
        idcs_train2 = np.setdiff1d(range(len(data2)), idcs_test2)
        
        # bias training set
        d1, l1, deleted1 = generateBias(data1[idcs_train1], labels1[idcs_train1], num_bias, prob=0, seed=seed+2)
        d2, l2, deleted2 = generateBias(data2[idcs_train2], labels2[idcs_train2], num_bias, prob=0, seed=seed+3)
        
        # concatenate
        train = np.concatenate((data1[idcs_train1], data2[idcs_train2]))
        l_train = np.append([0]*len(idcs_train1), [1]*len(idcs_train2))
        test = np.concatenate((data1[idcs_test1], data2[idcs_test2]))
        l_test = np.append([0]*len(idcs_test1), [1]*len(idcs_test2))
        train_b = np.concatenate((d1, d2))
        l_b = np.append([0]*len(l1), [1]*len(l2))
        deleted = np.append(deleted1, deleted2+len(idcs_train1))
        
        # calculate accuracies
        sample = np.random.randint(0, len(l_train), 300)
        acc_full = clf.fit(train[sample], l_train[sample]).score(test, l_test)
        sample = np.random.randint(0, len(l_b), 300)
        acc_bias = clf.fit(train_b[sample], l_b[sample]).score(test, l_test)
        if acc_full - acc_bias >= drop_min:
            if plot: plotBias(train, l_train, deleted, title="Accuracy drop: "+str(acc_full - acc_bias))
            print("Seed: ", seed)
            return train, l_train, test, l_test, train_b, l_b, deleted, seed
        seed += 4

# %%
# if we select the number of components via bic
def fit_gmm(data, max_clusters=50):
    best_bic = np.Inf
    for c in range(1, max_clusters):
        gm = GaussianMixture(n_components=c, random_state=0).fit(data)
        if gm.bic(data) < best_bic: 
            best_comp = c
            best_bic = gm.bic(data)

    gm = GaussianMixture(n_components=best_comp, random_state=0).fit(data)
    return list(zip(gm.means_, gm.covariances_))

# %%
def augment_multiClass_gmm(data, labels):
    points = []
    point_labels = []
    clusters = 0
    for c in np.unique(labels):
        gm_params = fit_gmm(data[labels==c])
        aug_p, _ = augment(data[labels==c], gm_params, plots=False, purge=False)
        points.append(aug_p)
        point_labels.append([c]*len(aug_p))
        clusters += len(gm_params)
    return np.concatenate(points), np.concatenate(point_labels), clusters

# %%
def augment_multiClass_mimic(data, labels):
    points = []
    point_labels = []
    clusters = 0
    for c in np.unique(labels):
        _, imi_params = fit(data[labels==c], plots=False)
        aug_p, _ = augment(data[labels==c], imi_params, plots=False, purge=False)
        points.append(aug_p)
        point_labels.append([c]*len(aug_p))
        clusters += len(imi_params)
    return np.concatenate(points), np.concatenate(point_labels), clusters

# %%
def augment_multiClass_imi(data, labels):
    points = []
    point_labels = []
    for c in np.unique(labels):
        aug_p, _ = Imitate_augment(data[labels==c], np.array([0]*np.sum(labels==c)))
        points.append(aug_p)
        point_labels.append([c]*len(aug_p))
    return np.concatenate(points), np.concatenate(point_labels), len(np.unique(labels))

# %% [markdown]
# # Spread

# %%
# # initialize file
# f = open("Results/exp_predictionAcc_spread.txt", "w") # a is append, w is write
# f.write("seed,num_clusters,num_dims,spread,clf,optimal,biased,method,augmented_acc,added_points")
# f.close()

# %%
def run_experiment_spread(num_clusters, num_dims, spread, filename, rep=10):
    clfs = [DecisionTreeClassifier(), SVC(), RandomForestClassifier()]
    clf_names = ['DT', 'SVM', 'RF']
    for r in range(rep):
        seed = np.random.randint(1000, 9999)
        X_tr, y_tr, X_te, y_te, X_b, y_b, _, seed = generate_evil_data(5000, num_clusters, num_dims, num_clusters, 
                                                                       drop_min=0.10, spread=spread, seed=seed)
        
        p_gmm, l_gmm = augment_multiClass_gmm(X_b, y_b)
        X_gmm, y_gmm = np.concatenate((X_b, p_gmm)), np.append(y_b, l_gmm)
        
        p_imi, l_imi = augment_multiClass_imi(X_b, y_b)
        X_imi, y_imi = np.concatenate((X_b, p_imi)), np.append(y_b, l_imi)
        
        try:
            p_mim, l_mim = augment_multiClass_mimic(X_b, y_b)
            X_mim, y_mim = np.concatenate((X_b, p_mim)), np.append(y_b, l_mim)
        except:
            print(str(seed)+","+str(num_clusters)+","+str(num_dims), "broken")
            continue
        
        f = open("Results/"+filename+".txt", "a")
        for i in range(len(clfs)):
            o = clfs[i].fit(X_tr, y_tr).score(X_te, y_te) # original
            b = clfs[i].fit(X_b, y_b).score(X_te, y_te) # biased
            a_gmm = clfs[i].fit(X_gmm, y_gmm).score(X_te, y_te)
            a_imi = clfs[i].fit(X_imi, y_imi).score(X_te, y_te)
            a_mim = clfs[i].fit(X_mim, y_mim).score(X_te, y_te)

            fixed = "\n"+str(seed)+","+str(num_clusters)+","+str(num_dims)+","+str(spread)+","+clf_names[i]+","+str(o)+","+str(b)
            f.write(fixed+",GMM,"+str(a_gmm)+","+str(len(l_gmm)))
            f.write(fixed+",Imitate,"+str(a_imi)+","+str(len(l_imi)))
            f.write(fixed+",Mimic (ours),"+str(a_mim)+","+str(len(l_mim)))
        f.close()

# %%
for cl in range(1, 6):
    for dims in [2]:
        for spread in [10, 50, 100, 150, 200]:
            print("Starting", cl, "clusters and", dims, "dimensions with", spread, "spread")
            run_experiment_spread(cl, dims, spread, rep=25)
# Out:
# Starting 1 clusters and 2 dimensions with 10 spread
# Seed:  5333
# Seed:  9557
# Seed:  3515
# Seed:  2023
# Seed:  4975
# Seed:  3022
# Seed:  5636
# Seed:  8638
# Seed:  7862
# 7862,1,2 broken
# Seed:  5773
# Seed:  5398
# Seed:  3567
# Seed:  5952
# Seed:  5986
# Seed:  1160
# Seed:  9299
# Seed:  8905
# Seed:  6542
# Seed:  9902
# Seed:  5803
# 5803,1,2 broken
# Seed:  4250
# Seed:  5098
# Seed:  1564
# 1564,1,2 broken
# Seed:  2438
# Seed:  7418
# Starting 1 clusters and 2 dimensions with 50 spread
# Seed:  9407
# Seed:  3355
# Seed:  1102
# Seed:  3477
# Seed:  9457
# Seed:  9823
# Seed:  2690
# Seed:  3963
# Seed:  2134
# Seed:  5198
# 5198,1,2 broken
# Seed:  1646
# Seed:  6590
# Seed:  2702
# Seed:  5371
# Seed:  7280
# Seed:  8904
# Seed:  7257
# Seed:  3997
# Seed:  1691
# Seed:  7417
# Seed:  5745
# Seed:  2990
# Seed:  2987
# 2987,1,2 broken
# Seed:  4705
# Seed:  1289
# Starting 1 clusters and 2 dimensions with 100 spread
# Seed:  9179
# Seed:  4380
# Seed:  8824
# Seed:  5630
# Seed:  1560
# Seed:  4557
# Seed:  7138
# Seed:  4787
# 4787,1,2 broken
# Seed:  4658
# Seed:  9373
# Seed:  6203
# 6203,1,2 broken
# Seed:  5630
# Seed:  5430
# Seed:  9431
# Seed:  3372
# Seed:  8184
# Seed:  5635
# Seed:  7453
# Seed:  8524
# Seed:  6062
# Seed:  9958
# Seed:  8239
# Seed:  1779
# Seed:  1074
# Seed:  6831
# Starting 1 clusters and 2 dimensions with 150 spread
# Seed:  5260
# Seed:  6290
# 6290,1,2 broken
# Seed:  8717
# Seed:  9689
# 9689,1,2 broken
# Seed:  9728
# Seed:  3770
# Seed:  8232
# Seed:  4891
# Seed:  4604
# Seed:  3233
# Seed:  4605
# Seed:  5783
# Seed:  3353
# Seed:  9130
# 9130,1,2 broken
# Seed:  9188
# Seed:  2242
# Seed:  4705
# Seed:  8989
# Seed:  4280
# Seed:  8963
# Seed:  3424
# Seed:  10129
# Seed:  6110
# Seed:  6843
# Seed:  4439
# Starting 1 clusters and 2 dimensions with 200 spread
# Seed:  6814
# Seed:  4063
# Seed:  2607
# Seed:  7883
# Seed:  6488
# Seed:  4160
# Seed:  2607
# Seed:  4785
# Seed:  2357
# Seed:  1342
# Seed:  6590
# Seed:  1698
# Seed:  8659
# Seed:  9130
# Seed:  8232
# Seed:  3538
# Seed:  7496
# Seed:  2357
# Seed:  9776
# Seed:  3538
# Seed:  9468
# Seed:  4280
# Seed:  9468
# Seed:  2654
# Seed:  6918
# Starting 2 clusters and 2 dimensions with 10 spread
# Seed:  2626
# Seed:  5773
# Seed:  5003
# Seed:  4377
# Seed:  8037
# Seed:  1360
# Seed:  7170
# Seed:  5270
# Seed:  4612
# Seed:  9238
# Seed:  4385
# Seed:  3352
# 3352,2,2 broken
# Seed:  4403
# Seed:  7174
# Seed:  5868
# Seed:  2116
# Seed:  3075
# Seed:  6198
# Seed:  5885
# Seed:  9182
# Seed:  5204
# Seed:  4146
# Seed:  3407
# Seed:  7050
# Seed:  2602
# Starting 2 clusters and 2 dimensions with 50 spread
# Seed:  7671
# Seed:  3200
# Seed:  9948
# Seed:  3827
# Seed:  6984
# Seed:  1739
# Seed:  2155
# Seed:  8683
# Seed:  6329
# Seed:  1737
# Seed:  3595
# Seed:  4857
# Seed:  8249
# Seed:  7198
# Seed:  4499
# Seed:  1266
# Seed:  6688
# Seed:  6207
# Seed:  9559
# Seed:  4567
# Seed:  5323
# Seed:  9312
# Seed:  4857
# Seed:  3950
# Seed:  1556
# Starting 2 clusters and 2 dimensions with 100 spread
# Seed:  4209
# Seed:  4648
# Seed:  7706
# Seed:  6820
# Seed:  2273
# Seed:  3560
# Seed:  1137
# Seed:  4802
# Seed:  1482
# Seed:  7385
# Seed:  7721
# Seed:  4821
# Seed:  1359
# Seed:  6982
# Seed:  8472
# Seed:  2438
# Seed:  8513
# Seed:  8090
# Seed:  8418
# Seed:  9099
# Seed:  2830
# Seed:  2613
# Seed:  4431
# Seed:  1688
# Seed:  7385
# Starting 2 clusters and 2 dimensions with 150 spread
# Seed:  3088
# Seed:  5527
# Seed:  6760
# Seed:  8607
# Seed:  4605
# Seed:  8705
# Seed:  9964
# Seed:  1993
# Seed:  3771
# Seed:  1988
# Seed:  1770
# Seed:  1669
# Seed:  8824
# Seed:  9117
# Seed:  2533
# Seed:  5793
# Seed:  5732
# Seed:  4026
# Seed:  9144
# Seed:  3710
# Seed:  3397
# Seed:  7263
# Seed:  5259
# Seed:  2718
# Seed:  9552
# Starting 2 clusters and 2 dimensions with 200 spread
# Seed:  11519
# Seed:  7012
# Seed:  2771
# Seed:  4270
# Seed:  8607
# Seed:  1376
# Seed:  6943
# Seed:  5776
# Seed:  6919
# Seed:  1543
# Seed:  10633
# Seed:  5869
# Seed:  2771
# Seed:  4261
# Seed:  1669
# Seed:  3967
# Seed:  4946
# Seed:  3007
# Seed:  5776
# Seed:  3755
# Seed:  4762
# Seed:  8695
# Seed:  7394
# Seed:  8289
# Seed:  8607
# Starting 3 clusters and 2 dimensions with 10 spread
# Seed:  5020
# Seed:  3800
# Seed:  3267
# Seed:  7581
# Seed:  3855
# Seed:  9973
# Seed:  9145
# Seed:  6610
# Seed:  1653
# Seed:  1663
# Seed:  8638
# 8638,3,2 broken
# Seed:  7495
# Seed:  6914
# Seed:  6612
# Seed:  6189
# Seed:  7518
# Seed:  9674
# Seed:  1252
# Seed:  1344
# Seed:  9512
# Seed:  3400
# Seed:  4497
# Seed:  2456
# Seed:  1368
# Seed:  3998
# Starting 3 clusters and 2 dimensions with 50 spread
# Seed:  4964
# Seed:  2402
# Seed:  2010
# Seed:  7021
# Seed:  7074
# Seed:  3273
# Seed:  8359
# Seed:  9812
# Seed:  7048
# Seed:  6234
# Seed:  2093
# Seed:  7130
# Seed:  1140
# Seed:  3031
# Seed:  6186
# Seed:  1428
# Seed:  1229
# Seed:  2083
# Seed:  8464
# Seed:  6080
# Seed:  4947
# Seed:  4908
# Seed:  3196
# Seed:  8792
# Seed:  3680
# Starting 3 clusters and 2 dimensions with 100 spread
# Seed:  1655
# Seed:  6121
# Seed:  4790
# Seed:  2896
# Seed:  6428
# Seed:  7476
# Seed:  7705
# Seed:  9029
# Seed:  4462
# Seed:  4347
# Seed:  3452
# Seed:  6467
# Seed:  6189
# Seed:  5074
# Seed:  9545
# Seed:  9560
# Seed:  5904
# Seed:  5101
# Seed:  2461
# Seed:  8590
# Seed:  5904
# Seed:  1149
# Seed:  9127
# Seed:  9051
# Seed:  3970
# Starting 3 clusters and 2 dimensions with 150 spread
# Seed:  1457
# Seed:  5280
# Seed:  5797
# Seed:  9148
# Seed:  4020
# Seed:  3660
# Seed:  1360
# Seed:  10069
# Seed:  8676
# Seed:  2375
# Seed:  2691
# Seed:  3749
# Seed:  6290
# Seed:  1575
# Seed:  4932
# Seed:  8770
# Seed:  3864
# Seed:  6855
# Seed:  5299
# Seed:  5776
# Seed:  1550
# Seed:  9774
# Seed:  9035
# Seed:  1301
# Seed:  6567
# Starting 3 clusters and 2 dimensions with 200 spread
# Seed:  9213
# Seed:  1590
# Seed:  6444
# Seed:  5528
# Seed:  6330
# Seed:  3516
# Seed:  2668
# Seed:  8031
# Seed:  7705
# Seed:  7928
# Seed:  2547
# Seed:  1099
# Seed:  9213
# Seed:  6856
# Seed:  6589
# Seed:  3329
# Seed:  9196
# Seed:  7780
# Seed:  3483
# Seed:  4907
# Seed:  2273
# Seed:  3984
# Seed:  4759
# Seed:  6529
# Seed:  6330
# Starting 4 clusters and 2 dimensions with 10 spread
# Seed:  7838
# Seed:  8724
# Seed:  3264
# Seed:  8600
# Seed:  6866
# Seed:  7212
# Seed:  2183
# Seed:  7903
# Seed:  2939
# Seed:  5392
# Seed:  7085
# Seed:  1272
# Seed:  6151
# Seed:  7275
# Seed:  6065
# Seed:  4903
# Seed:  3880
# Seed:  7449
# Seed:  4024
# Seed:  3534
# Seed:  8505
# Seed:  5299
# Seed:  4048
# Seed:  1463
# Seed:  4585
# Starting 4 clusters and 2 dimensions with 50 spread
# Seed:  4404
# Seed:  2377
# Seed:  3036
# Seed:  4249
# Seed:  8190
# Seed:  4395
# Seed:  6213
# Seed:  4795
# Seed:  4187
# Seed:  7308
# Seed:  1051
# Seed:  4180
# Seed:  5078
# Seed:  7687
# Seed:  3144
# Seed:  2456
# Seed:  5029
# Seed:  1651
# Seed:  9459
# Seed:  3625
# Seed:  3452
# Seed:  3026
# Seed:  6975
# Seed:  8167
# Seed:  6940
# Starting 4 clusters and 2 dimensions with 100 spread
# Seed:  3983
# Seed:  7634
# Seed:  3513
# Seed:  4730
# Seed:  3512
# Seed:  9283
# Seed:  7721
# Seed:  8167
# Seed:  3735
# Seed:  3450
# Seed:  3916
# Seed:  7899
# Seed:  3124
# Seed:  6007
# Seed:  2943
# Seed:  3598
# Seed:  4605
# Seed:  3075
# Seed:  5374
# Seed:  1213
# Seed:  5906
# Seed:  2828
# Seed:  9358
# Seed:  9538
# Seed:  7947
# Starting 4 clusters and 2 dimensions with 150 spread
# Seed:  5670
# Seed:  8507
# Seed:  10456
# Seed:  2353
# Seed:  9899
# Seed:  5703
# Seed:  1106
# Seed:  3519
# Seed:  6159
# Seed:  3293
# Seed:  9024
# Seed:  9077
# Seed:  9770
# Seed:  8000
# Seed:  4093
# Seed:  7712
# Seed:  3513
# Seed:  9806
# Seed:  4074
# Seed:  9649
# Seed:  4952
# Seed:  8131
# Seed:  9170
# Seed:  5985
# Seed:  10027
# Starting 4 clusters and 2 dimensions with 200 spread
# Seed:  8073
# Seed:  8610
# Seed:  7331
# Seed:  4787
# Seed:  8953
# Seed:  1374
# Seed:  6791
# Seed:  2703
# Seed:  1469
# Seed:  6424
# Seed:  4806
# Seed:  3293
# Seed:  4787
# Seed:  5670
# Seed:  8617
# Seed:  5985
# Seed:  9425
# Seed:  6234
# Seed:  6166
# Seed:  9717
# Seed:  7331
# Seed:  5745
# Seed:  5669
# Seed:  9445
# Seed:  6234
# Starting 5 clusters and 2 dimensions with 10 spread
# Seed:  4969
# Seed:  4249
# Seed:  1255
# Seed:  2974
# Seed:  9046
# Seed:  7773
# Seed:  7475
# Seed:  8119
# Seed:  6919
# Seed:  7890
# Seed:  7256
# Seed:  5265
# Seed:  3304
# Seed:  6773
# Seed:  1255
# Seed:  3257
# Seed:  7082
# Seed:  9832
# Seed:  2030
# Seed:  2532
# Seed:  1876
# Seed:  3861
# Seed:  6261
# Seed:  1133
# Seed:  5087
# Starting 5 clusters and 2 dimensions with 50 spread
# Seed:  7140
# Seed:  6860
# Seed:  10093
# Seed:  9366
# Seed:  2152
# Seed:  6031
# Seed:  8151
# Seed:  4881
# Seed:  4413
# Seed:  6559
# Seed:  2635
# Seed:  1477
# Seed:  2166
# Seed:  5573
# Seed:  9327
# Seed:  9418
# Seed:  9079
# 9079,5,2 broken
# Seed:  9068
# Seed:  8909
# Seed:  9773
# Seed:  3538
# Seed:  8391
# Seed:  3964
# Seed:  9026
# Seed:  2708
# Starting 5 clusters and 2 dimensions with 100 spread
# Seed:  4548
# Seed:  2033
# Seed:  5307
# Seed:  4660
# Seed:  2387
# Seed:  3266
# Seed:  3372
# Seed:  4562
# Seed:  3789
# Seed:  9548
# Seed:  4538
# Seed:  6634
# Seed:  2123
# Seed:  8536
# Seed:  1670
# Seed:  7371
# Seed:  8201
# Seed:  8946
# Seed:  7954
# Seed:  3881
# Seed:  1248
# Seed:  9950
# Seed:  2033
# Seed:  6919
# Seed:  8239
# Starting 5 clusters and 2 dimensions with 150 spread
# Seed:  1248
# Seed:  6307
# Seed:  5450
# Seed:  8512
# Seed:  8084
# Seed:  8748
# Seed:  1222
# Seed:  5205
# Seed:  2843
# Seed:  2755
# Seed:  4785
# Seed:  2309
# Seed:  9528
# Seed:  6774
# Seed:  2387
# Seed:  8005
# Seed:  2109
# Seed:  7494
# Seed:  8084
# Seed:  5440
# Seed:  7505
# Seed:  1259
# Seed:  9328
# Seed:  5021
# Seed:  4960
# Starting 5 clusters and 2 dimensions with 200 spread
# Seed:  7288
# Seed:  4959
# Seed:  7566
# Seed:  3429
# Seed:  6885
# Seed:  1876
# Seed:  4043
# Seed:  7727
# Seed:  4959
# Seed:  10417
# Seed:  5034
# Seed:  7079
# Seed:  8718
# Seed:  5958
# Seed:  6927
# Seed:  3598
# Seed:  6470
# Seed:  2879
# Seed:  5746
# Seed:  2454
# 2454,5,2 broken
# Seed:  7433
# Seed:  4825
# Seed:  2775
# Seed:  4932
# Seed:  7288

# %% [markdown]
# # Dimensions

# %%
# # initialize file
# f = open("Results/exp_predictionAcc_dims.txt", "w") # a is append, w is write
# f.write("seed,num_clusters,num_dims,spread,clf,optimal,biased,method,augmented_acc,added_points")
# f.close()

# %%
for cl in range(1, 6):
    for dims in [2, 3, 4, 5]:
        for spread in [100]:
            print("Starting", cl, "clusters and", dims, "dimensions with", spread, "spread")
            run_experiment_spread(cl, dims, spread, rep=30, filename="exp_predictionAcc_dims")
# Out:
# Starting 1 clusters and 2 dimensions with 100 spread
# Seed:  8217
# Seed:  7546
# Seed:  7987
# Seed:  8902
# Seed:  8574
# 8574,1,2 broken
# Seed:  9130
# Seed:  1443
# Seed:  4345
# Seed:  8249
# Seed:  1779
# Seed:  1965
# Seed:  1467
# Seed:  1965
# Seed:  9061
# Seed:  9159
# Seed:  8185
# Seed:  8184
# Seed:  8184
# Seed:  6745
# Seed:  2242
# Seed:  9377
# Seed:  2314
# Seed:  9244
# Seed:  9958
# Seed:  8184
# Seed:  8574
# Seed:  1670
# Seed:  5437
# Seed:  1948
# Seed:  6375
# Starting 1 clusters and 3 dimensions with 100 spread
# Seed:  9972
# Seed:  4279
# Seed:  8076
# Seed:  4674
# 4674,1,3 broken
# Seed:  8449
# Seed:  4749
# 4749,1,3 broken
# Seed:  5602
# Seed:  4810
# Seed:  4345
# Seed:  4618
# Seed:  2112
# Seed:  6620
# 6620,1,3 broken
# Seed:  5069
# 5069,1,3 broken
# Seed:  10090
# Seed:  1171
# Seed:  6918
# Seed:  8551
# Seed:  7570
# 7570,1,3 broken
# Seed:  1895
# 1895,1,3 broken
# Seed:  7989
# Seed:  3183
# Seed:  7465
# Seed:  3361
# 3361,1,3 broken
# Seed:  4217
# 4217,1,3 broken
# Seed:  3319
# Seed:  8609
# Seed:  8076
# 8076,1,3 broken
# Seed:  7539
# 7539,1,3 broken
# Seed:  8968
# Seed:  3592
# Starting 1 clusters and 4 dimensions with 100 spread
# Seed:  5643
# 5643,1,4 broken
# Seed:  4701
# 4701,1,4 broken
# Seed:  1352
# Seed:  6221
# Seed:  9802
# 9802,1,4 broken
# Seed:  6879
# Seed:  3105
# 3105,1,4 broken
# Seed:  3940
# Seed:  9909
# 9909,1,4 broken
# Seed:  9721
# Seed:  8438
# 8438,1,4 broken
# Seed:  1800
# 1800,1,4 broken
# Seed:  6036
# 6036,1,4 broken
# Seed:  1149
# Seed:  5183
# 5183,1,4 broken
# Seed:  3488
# Seed:  4422
# Seed:  5704
# Seed:  3383
# Seed:  5576
# Seed:  3383
# 3383,1,4 broken
# Seed:  9254
# 9254,1,4 broken
# Seed:  9721
# Seed:  7374
# 7374,1,4 broken
# Seed:  8891
# Seed:  2021
# 2021,1,4 broken
# Seed:  3105
# 3105,1,4 broken
# Seed:  3394
# 3394,1,4 broken
# Seed:  3997
# Seed:  4464
# Starting 1 clusters and 5 dimensions with 100 spread
# Seed:  3856
# 3856,1,5 broken
# Seed:  8248
# 8248,1,5 broken
# Seed:  6000
# 6000,1,5 broken
# Seed:  1241
# 1241,1,5 broken
# Seed:  4704
# Seed:  8830
# 8830,1,5 broken
# Seed:  3015
# Seed:  7429
# Seed:  8976
# 8976,1,5 broken
# Seed:  6879
# 6879,1,5 broken
# Seed:  7884
# 7884,1,5 broken
# Seed:  2531
# Seed:  6560
# 6560,1,5 broken
# Seed:  7642
# 7642,1,5 broken
# Seed:  8251
# 8251,1,5 broken
# Seed:  6035
# 6035,1,5 broken
# Seed:  5253
# 5253,1,5 broken
# Seed:  3339
# 3339,1,5 broken
# Seed:  6994
# 6994,1,5 broken
# Seed:  1701
# 1701,1,5 broken
# Seed:  2387
# 2387,1,5 broken
# Seed:  4443
# Seed:  5253
# 5253,1,5 broken
# Seed:  8611
# 8611,1,5 broken
# Seed:  5253
# 5253,1,5 broken
# Seed:  6879
# 6879,1,5 broken
# Seed:  3857
# 3857,1,5 broken
# Seed:  6000
# 6000,1,5 broken
# Seed:  5328
# 5328,1,5 broken
# Seed:  5147
# 5147,1,5 broken
# Starting 2 clusters and 2 dimensions with 100 spread
# Seed:  9586
# Seed:  6539
# Seed:  8973
# Seed:  8926
# Seed:  3007
# Seed:  7611
# Seed:  3278
# Seed:  3504
# Seed:  3780
# Seed:  6248
# Seed:  7857
# Seed:  8194
# Seed:  1654
# Seed:  8399
# Seed:  5748
# Seed:  2820
# Seed:  4922
# Seed:  6103
# Seed:  3868
# Seed:  9782
# Seed:  1482
# Seed:  1603
# Seed:  1993
# Seed:  3339
# Seed:  7826
# Seed:  7263
# Seed:  1603
# Seed:  8803
# Seed:  1180
# Seed:  3868
# Starting 2 clusters and 3 dimensions with 100 spread
# Seed:  7971
# Seed:  7040
# Seed:  2162
# Seed:  9280
# Seed:  9114
# Seed:  6075
# Seed:  1642
# Seed:  2039
# Seed:  6733
# Seed:  7674
# Seed:  3085
# Seed:  7240
# Seed:  4702
# Seed:  8077
# Seed:  6358
# Seed:  6174
# Seed:  6563
# Seed:  9107
# Seed:  2469
# Seed:  5171
# Seed:  4492
# Seed:  6173
# 6173,2,3 broken
# Seed:  8821
# Seed:  2938
# Seed:  3188
# Seed:  5432
# Seed:  9903
# Seed:  3916
# Seed:  3813
# Seed:  3188
# Starting 2 clusters and 4 dimensions with 100 spread
# Seed:  8466
# Seed:  2428
# Seed:  3855
# Seed:  5263
# Seed:  4428
# Seed:  5462
# Seed:  3171
# Seed:  1800
# Seed:  3767
# Seed:  3171
# Seed:  10140
# Seed:  7014
# Seed:  3606
# Seed:  1548
# Seed:  7830
# Seed:  8666
# Seed:  6783
# Seed:  10293
# Seed:  3855
# Seed:  10140
# Seed:  9404
# Seed:  4276
# Seed:  5943
# Seed:  3998
# Seed:  10269
# Seed:  6541
# Seed:  8466
# Seed:  7582
# Seed:  10227
# Seed:  2536
# Starting 2 clusters and 5 dimensions with 100 spread
# Seed:  2894
# Seed:  3963
# Seed:  4385
# Seed:  10828
# Seed:  2419
# Seed:  4444
# Seed:  2341
# Seed:  11109
# Seed:  4291
# Seed:  4674
# 4674,2,5 broken
# Seed:  9084
# Seed:  5885
# Seed:  6022
# Seed:  4444
# Seed:  9206
# Seed:  9459
# Seed:  3969
# Seed:  1672
# Seed:  6538
# Seed:  9459
# Seed:  8469
# Seed:  8402
# Seed:  3189
# Seed:  9206
# Seed:  9206
# Seed:  9206
# Seed:  1809
# Seed:  4691
# Seed:  7556
# Seed:  3454
# 3454,2,5 broken
# Starting 3 clusters and 2 dimensions with 100 spread
# Seed:  3858
# Seed:  7331
# Seed:  3564
# Seed:  9431
# Seed:  4110
# Seed:  1132
# Seed:  8313
# Seed:  7780
# Seed:  3086
# Seed:  1981
# Seed:  4840
# Seed:  9694
# Seed:  2702
# Seed:  6790
# Seed:  9907
# Seed:  7928
# Seed:  6884
# Seed:  3563
# Seed:  10069
# Seed:  9161
# Seed:  1323
# Seed:  1499
# Seed:  5074
# Seed:  8396
# Seed:  1850
# Seed:  3325
# Seed:  5799
# Seed:  5874
# Seed:  5482
# Seed:  7563
# Starting 3 clusters and 3 dimensions with 100 spread
# Seed:  4908
# Seed:  6267
# Seed:  3777
# Seed:  3794
# Seed:  3707
# Seed:  8071
# Seed:  1428
# Seed:  4679
# Seed:  8795
# Seed:  7651
# Seed:  7424
# Seed:  8766
# Seed:  6760
# Seed:  8422
# Seed:  8753
# Seed:  7822
# Seed:  1669
# Seed:  7063
# Seed:  7338
# Seed:  4248
# Seed:  6731
# Seed:  4270
# Seed:  10316
# Seed:  9114
# Seed:  2522
# Seed:  2566
# Seed:  6428
# Seed:  8287
# Seed:  3699
# Seed:  9296
# Starting 3 clusters and 4 dimensions with 100 spread
# Seed:  3183
# Seed:  3183
# Seed:  6800
# Seed:  1915
# Seed:  5375
# Seed:  7577
# Seed:  8557
# Seed:  7624
# Seed:  2507
# Seed:  6823
# Seed:  6442
# Seed:  5608
# Seed:  9431
# Seed:  10133
# Seed:  2388
# Seed:  2032
# Seed:  1610
# Seed:  9470
# Seed:  9431
# Seed:  8836
# Seed:  10133
# Seed:  7546
# Seed:  8778
# Seed:  7638
# Seed:  4439
# Seed:  5392
# Seed:  6823
# Seed:  8942
# Seed:  8410
# Seed:  9722
# 9722,3,4 broken
# Starting 3 clusters and 5 dimensions with 100 spread
# Seed:  10339
# Seed:  4550
# Seed:  3943
# Seed:  5279
# Seed:  8248
# Seed:  4169
# Seed:  5279
# Seed:  8248
# Seed:  6944
# Seed:  3512
# Seed:  8248
# Seed:  5279
# Seed:  12710
# Seed:  7625
# Seed:  8643
# Seed:  5073
# Seed:  13490
# Seed:  10280
# Seed:  6576
# Seed:  7625
# Seed:  10210
# Seed:  6944
# Seed:  3514
# Seed:  6944
# Seed:  6944
# Seed:  2128
# Seed:  4169
# Seed:  10339
# Seed:  3907
# Seed:  10579
# Starting 4 clusters and 2 dimensions with 100 spread
# Seed:  4298
# Seed:  9986
# Seed:  2556
# Seed:  1585
# Seed:  7814
# Seed:  7632
# Seed:  5709
# Seed:  8785
# Seed:  9986
# Seed:  6900
# Seed:  4572
# Seed:  5500
# Seed:  6810
# Seed:  8891
# Seed:  5376
# Seed:  2556
# Seed:  2734
# Seed:  2604
# Seed:  2775
# Seed:  9430
# Seed:  9241
# Seed:  7709
# Seed:  7621
# Seed:  1458
# Seed:  5376
# Seed:  4453
# Seed:  8294
# Seed:  6484
# Seed:  7621
# Seed:  9180
# Starting 4 clusters and 3 dimensions with 100 spread
# Seed:  9324
# Seed:  4944
# Seed:  4876
# Seed:  2049
# Seed:  5267
# Seed:  8649
# Seed:  2272
# Seed:  5242
# Seed:  4280
# Seed:  2864
# Seed:  6587
# Seed:  3177
# Seed:  9339
# Seed:  2151
# Seed:  5821
# Seed:  10127
# Seed:  9528
# Seed:  8990
# Seed:  9972
# Seed:  2530
# Seed:  1824
# 1824,4,3 broken
# Seed:  9066
# Seed:  2455
# Seed:  10127
# Seed:  4433
# Seed:  9339
# Seed:  9751
# Seed:  8386
# Seed:  10771
# Seed:  8620
# Starting 4 clusters and 4 dimensions with 100 spread
# Seed:  4346
# Seed:  3342
# Seed:  7708
# Seed:  5926
# Seed:  10868
# Seed:  4158
# Seed:  6002
# Seed:  9256
# Seed:  11534
# Seed:  1358
# Seed:  3235
# Seed:  6145
# Seed:  6350
# Seed:  2402
# Seed:  6233
# Seed:  5058
# Seed:  12534
# Seed:  6188
# Seed:  1178
# Seed:  2056
# Seed:  6188
# Seed:  6445
# Seed:  1543
# 1543,4,4 broken
# Seed:  2467
# Seed:  8139
# Seed:  10254
# Seed:  7976
# Seed:  7291
# Seed:  5678
# Seed:  10000
# Starting 4 clusters and 5 dimensions with 100 spread
# Seed:  5966
# Seed:  9896
# Seed:  8206
# 8206,4,5 broken
# Seed:  9896
# Seed:  4182
# Seed:  2735
# Seed:  8206
# 8206,4,5 broken
# Seed:  10271
# Seed:  3210
# Seed:  4959
# Seed:  4701
# Seed:  9896
# Seed:  9711
# Seed:  9896
# Seed:  11364
# Seed:  9711
# Seed:  7405
# Seed:  4050
# 4050,4,5 broken
# Seed:  9711
# Seed:  7576
# Seed:  13283
# Seed:  9266
# Seed:  11364
# Seed:  8983
# Seed:  3765
# Seed:  8206
# 8206,4,5 broken
# Seed:  11364
# Seed:  9896
# Seed:  12005
# Seed:  7218
# Starting 5 clusters and 2 dimensions with 100 spread
# Seed:  2768
# Seed:  4538
# Seed:  2742
# Seed:  8064
# Seed:  3282
# Seed:  8989
# Seed:  6373
# Seed:  5396
# Seed:  2742
# Seed:  1627
# Seed:  3260
# Seed:  5440
# Seed:  6373
# Seed:  5286
# Seed:  9086
# Seed:  1897
# Seed:  9950
# Seed:  2972
# Seed:  7072
# Seed:  4089
# Seed:  9573
# Seed:  3669
# Seed:  3789
# Seed:  6232
# Seed:  5360
# Seed:  4887
# Seed:  8771
# Seed:  5545
# Seed:  3266
# Seed:  7510
# Starting 5 clusters and 3 dimensions with 100 spread
# Seed:  3655
# Seed:  7121
# Seed:  5158
# Seed:  9104
# Seed:  5280
# Seed:  5968
# Seed:  9224
# Seed:  3991
# Seed:  7435
# Seed:  6716
# Seed:  7748
# Seed:  6516
# Seed:  5431
# Seed:  6990
# Seed:  3146
# Seed:  9382
# Seed:  5020
# Seed:  1891
# Seed:  7264
# Seed:  6760
# Seed:  5203
# Seed:  8216
# Seed:  3744
# Seed:  5758
# Seed:  5315
# Seed:  1135
# Seed:  4031
# Seed:  5697
# Seed:  5450
# Seed:  6787
# Starting 5 clusters and 4 dimensions with 100 spread
# Seed:  10233
# Seed:  8207
# Seed:  9229
# Seed:  7994
# Seed:  4873
# Seed:  1427
# Seed:  9746
# Seed:  1714
# Seed:  4083
# Seed:  8312
# Seed:  4435
# Seed:  9388
# Seed:  5530
# Seed:  6409
# Seed:  12030
# Seed:  8768
# Seed:  8352
# Seed:  2453
# 2453,5,4 broken
# Seed:  9828
# Seed:  2247
# Seed:  9290
# Seed:  6306
# 6306,5,4 broken
# Seed:  8884
# 8884,5,4 broken
# Seed:  7994
# Seed:  4920
# Seed:  2428
# Seed:  4920
# Seed:  4248
# 4248,5,4 broken
# Seed:  4975
# Seed:  6786
# Starting 5 clusters and 5 dimensions with 100 spread
# Seed:  11003
# Seed:  19227
# Seed:  9496
# 9496,5,5 broken
# Seed:  8615
# Seed:  7706
# Seed:  8184
# Seed:  14819
# Seed:  5937
# Seed:  2888
# 2888,5,5 broken
# Seed:  14899
# 14899,5,5 broken
# Seed:  7652
# Seed:  24445
# 24445,5,5 broken
# Seed:  17446
# Seed:  3361
# 3361,5,5 broken
# Seed:  14840
# Seed:  10176
# Seed:  6913
# Seed:  5937
# Seed:  7151
# 7151,5,5 broken
# Seed:  22077
# Seed:  14819
# Seed:  7706
# Seed:  20752
# Seed:  1571
# Seed:  9129
# Seed:  5332
# Seed:  9203
# Seed:  17446
# Seed:  7896
# Seed:  7977
